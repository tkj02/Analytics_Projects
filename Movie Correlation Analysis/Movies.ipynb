# %%
# Imports libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# Specifies style sheet
plt.style.use('ggplot')

# Specifies in line plots and figure sizes
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8)

# Reads data
df = pd.read_csv('movies.csv')

# %%
# Preview of table
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Number of rows and columns in table
df.shape
# Out:
# (7668, 15)

# %%
# Data types of each column
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Function to identify rows with missing values
def col_missing_print():
    for col in df.columns:
        missing = sum(df[col].isnull())
        print(col+':', missing)

# Calls function
col_missing_print()
# Out:
# name: 0
# rating: 77
# genre: 0
# year: 0
# released: 2
# score: 3
# votes: 3
# director: 0
# writer: 3
# star: 1
# country: 3
# budget: 2171
# gross: 189
# company: 17
# runtime: 4

# %%
# Removes rows with missing values
df.dropna(inplace=True)

# %%
# Calls function to confirm all rows with missing entries were removed
col_missing_print()
# Out:
# name: 0
# rating: 0
# genre: 0
# year: 0
# released: 0
# score: 0
# votes: 0
# director: 0
# writer: 0
# star: 0
# country: 0
# budget: 0
# gross: 0
# company: 0
# runtime: 0

# %%
# New number of rows (7668 - 5421 = 2247 rows removed)
df.shape[0]
# Out:
# 5421

# %%
# Converting floats to ints
df['budget'] = df['budget'].astype('int64') 
df['gross'] = df['gross'].astype('int64')

# %%
# Isolates year from release date, creates year column
df['year'] = df['released'].astype(str).str.split().str[2]

# %%
# Sorts by highest to lowest gross revenue value
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2015
# 2434                  Philadelphia Experiment II      PG-13  Action  1994
# 3681                                Ginger Snaps  Not Rated   Drama  2001
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# Removes any duplicates
df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Scatter plot of budget vs gross revenue using Matplotlib
plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Revenue')
plt.xlabel('Budget (Millions)')
plt.ylabel('Gross Revenue (100 Millions)')

plt.show()

# %%
# Scatter plot of budget vs gross revenue plot using Seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'red'},
            line_kws={'color':'blue'})

plt.title('Budget vs Gross Revenue')
plt.xlabel('Budget (Millions)')
plt.ylabel('Gross Revenue (100 Millions)')

plt.show()

# %%
# Correlations using Pearson method
df.corr()
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# Heatmap of correlation using Pearson method
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Movie Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Converts categorical data into number representations
numerized_df = df

for col in numerized_df.columns:
    if (numerized_df[col].dtype == 'object'):
        numerized_df[col] = numerized_df[col].astype('category')
        numerized_df[col] = numerized_df[col].cat.codes
        
numerized_df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6     2      1304    8.4   927000.0      1795    2832
# 1     3929       6      1     2      1127    5.8    65000.0      1578    1158
# 2     3641       4      0     2      1359    8.7  1200000.0       757    1818
# 3      204       4      4     2      1127    7.7   221000.0       889    1413
# 4      732       6      4     2      1170    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0    42       904    6.6   140000.0        16    2390
# 7649  3556       4      0    42       713    6.5   102000.0       852    2309
# 7650  1153       4      1    42       904    5.6    53000.0      1809    2827
# 7651  3978       4      1    42       758    6.8    42000.0       294    2091
# 7652  4090       3      0    42       370    6.8     3700.0       746    1184
#
# ...

# %%
# Heatmap of correlation of numerized data using Pearson method
correlation_matrix = numerized_df.corr()
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Movie Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# View correlations of numerized data sorted and paired by feature
correlation_matrix = numerized_df.corr()
correlation_pairs = correlation_matrix.unstack()
sorted_pairs = correlation_pairs.sort_values()
sorted_pairs
# Out:
# budget   genre     -0.368523
# genre    budget    -0.368523
# gross    genre     -0.244101
# genre    gross     -0.244101
# budget   rating    -0.203946
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
high_correlation = sorted_pairs[(sorted_pairs) > 0.5]
high_correlation
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
